# %%
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot

hide_input()
# Out:
#         <a id="1822364030" href="javascript:toggle_input_1822364030()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1822364030;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1822364030 = document.getElementById("1822364030");
#                 var cell = link_1822364030;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1822364030;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1822364030 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1822364030 = cell.previousElementSibling;
#                 }
#                 input_1822364030.style.display = "none"; // hide
#
#                 toggle_input_1822364030 = function() {
#                     if (input_1822364030.style.display == "none") {
#                         input_1822364030.style.display = ""; // show
#                         link_1822364030.innerHTML = "Hide Input";
#                     } else {
#                         input_1822364030.style.display = "none"; // hide
#                         link_1822364030.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1822364030 = $("a[id='1822364030']");
#                 var cell_1822364030 = link_1822364030.parents("div.cell:first");
#                 if (cell_1822364030.length == 0) {
#                     cell_1822364030 = link_1822364030.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1822364030 = cell_1822364030.children("div.input");
#                 if (input_1822364030.length == 0) {
#                     input_1822364030 = cell_1822364030.prev("div.nbinput");
#                 }
#                 input_1822364030.hide();
#
#                 toggle_input_1822364030 = function() {
#                     if (input_1822364030.is(':hidden')) {
#                         input_1822364030.slideDown();
#                         link_1822364030[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1822364030.slideUp();
#                         link_1822364030[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Goal: Sum tuning curves scalar fields by neuron weights.

# %%
model = nengo.Network()

with model:

    n_neurons = 1
    # Let the `given` ensemble have n_neurons neurons
    given = nengo.Ensemble(
        n_neurons=n_neurons,
        dimensions=2,seed=0
    )

    # perform experiment 3 times
    nengo.Connection(nengo.Node(1), given[0])
    nengo.Connection(nengo.Node(0), given[1])
    #
    # # Create dummy ensemble to read dendrite weights
    # dummy = nengo.Ensemble(64,dimensions=3,)
    #
    # # The 3 dendrites will generate soma currents:
    # # cos(8t)
    # conn0 = nengo.Connection(given[0], dummy[0], function=lambda x : x)
    # # cos^2(8t)
    # conn1 = nengo.Connection(given[1], dummy[1], function=lambda x : x ** 2)
    # # 0.5
    # conn2 = nengo.Connection(given[2], dummy[2], function=lambda x : 0.5)


    D_spikes = nengo.Probe(given.neurons)
    D_PSC = nengo.Probe(given.neurons, synapse=0.01)
    D_dims = nengo.Probe(given, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)
    eval_points, activities = tuning_curves(given, sim)
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('1288b19f-5b90-4340-8a56-046d7846b77a');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:01.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('b6bfc25e-5a91-49ee-856e-3a373c2d8e48');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Simulation finished in 0:00:01.';
#
#             if (100.0 > 0.) {
#                 fill.style.transition = 'width 0.1s linear';
#             } else {
#                 fill.style.transition = 'none';
#             }
#
#             fill.style.width = '100.0%';
#             fill.style.animation = 'none';
#             fill.style.backgroundImage = 'none'
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>

# %%
rasterplot(sim.trange(), sim.data[D_spikes])
plt.ylabel("Neuron")
plt.xlabel("Time (s)")
plt.title('Spiking activity of each neuron in given ensemble')
plt.show()

# %%
plt.figure(figsize=(8, 8))
ax = plt.subplot(projection="3d")
ax.set_title("Tuning curve of all neurons")
for i in range(given.n_neurons):
    ax.plot_surface(
        eval_points.T[0], eval_points.T[1], activities.T[i], cmap=plt.cm.autumn
    )

# %%
plt.plot(sim.trange(),sim.data[D_PSC])
